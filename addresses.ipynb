# %%
import os
import pandas as pd
from openai import OpenAI
from typing import Dict
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Address Lists

# %%
addresses = [
    {"address": '"95-10 Ditmars Boulevard, Queens, New York, 11369"', "property_type": "Automobile Dealership"},
    {"address": '"1800 Shore Pkwy, Brooklyn, New York, 11214"', "property_type": "Automobile Dealership"},
    {"address": '"40-40 Northern Boulevard, Queens, New York, 11101"', "property_type": "Automobile Dealership"},
    {"address": '"69-10 34 Avenue, Queens Borough, New York, 11377"', "property_type": "Bowling Alley"},
    {"address": '"1600 Hylan Boulevard, Staten Island, New York, 10305"', "property_type": "Bowling Alley"},
    {"address": '"2417 HOLLERS AVENUE, Bronx, New York, 10475"', "property_type": "Bowling Alley"},
    {"address": '"1121 Bedford Ave, Brooklyn, New York, 11216"', "property_type": "Fitness Center / Health Club / Gym"},
    {"address": '"330 E 61ST ST NEW YORK NY, NEW YORK, New York, 10065"', "property_type": "Fitness Center / Health Club / Gym"},
    {"address": '"505 West 218th Street, New York, New York, 10034"', "property_type": "Fitness Center / Health Club / Gym"},
    {"address": '"28-56 Steinway St, Queens, New York, 11103"', "property_type": "Fitness Center / Health Club / Gym"},
    {"address": '"207 Beach 73rd St, Averne, New York, 11692"', "property_type": "Fitness Center / Health Club / Gym"},
    {"address": '"897 BROADWAY NEW YORK, NEW YORK, New York, 10003"', "property_type": "Fitness Center / Health Club / Gym"},
    {"address": '"363 West 16th Street, New York, New York, 10011"', "property_type": "Hotel"},
    {"address": '"848 Washington Street, Manhattan, New York, 10014"', "property_type": "Hotel"},
    {"address": '"147 W 43rd St, New York, New York, 10036"', "property_type": "Hotel"},
    {"address": '"212 East 42nd Street, New York, New York, 10017"', "property_type": "Hotel"},
    {"address": '"1535 Broadway, New York, New York, 10036"', "property_type": "Hotel"},
    {"address": '"130 West 44th Street, Manhattan, New York, 10036"', "property_type": "Hotel"},
    {"address": '"377 Greenwich Street, New York, New York, 10013"', "property_type": "Hotel"},
    {"address": '"40 West 40th Street, New York, New York, 10001"', "property_type": "Hotel"},
    {"address": '"377 Greenwich St, New York, New York, 10013"', "property_type": "Hotel"},
    {"address": '"335 Bowery, New York, New York, 10003"', "property_type": "Hotel"},
    {"address": '"308 West 58th Street, New York, New York, 10019"', "property_type": "Hotel"},
    {"address": '"29 9th Avenue, New York, New York, 10014"', "property_type": "Hotel"},
    {"address": '"97 Wythe Avenue, NYC, New York, 11249"', "property_type": "Hotel"},
    {"address": '"80 Wythe Ave, Brooklyn, New York, 11249"', "property_type": "Hotel"},
    {"address": '"96 Wythe Ave, Brooklyn, NY 11249, Brooklyn, New York, 11249"', "property_type": "Hotel"},
    {"address": '"95 West Broadway, New York, New York, 10007"', "property_type": "Hotel"},
    {"address": '"210 W 55th St, New York, New York, 10019"', "property_type": "Hotel"},
    {"address": '"361 Bedford Ave, Brooklyn, New York, 11211"', "property_type": "Hotel"},
    {"address": '"210 WEST 55 STREET, NEW YORK, New York, 10019"', "property_type": "Hotel"},
    {"address": '"189 Bowery Street, New York, New York, 10002"', "property_type": "Hotel"},
    {"address": '"405 East 73rd Street, New York, New York, 10021"', "property_type": "Hotel"},
', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"5860 GRAND AVE, Queens, New York, 11378"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"1201 Metropolitan Ave, Brooklyn, New York, 11237"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"47-20 30 STREET, QUEENS, New York, 11101"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"115-40 DUNKIRK STREET, QUEENS, New York, 11412"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"150-10 132nd Ave., jamaica, New York, 11434"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"56-01 Maspeth Ave, Queens, New York, 11378"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"333 Beach 95th Street AKA 95-15 Beach Channel Drive, Queens, New York, 11693"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"10615 Foster Avenue, Brooklyn, New York, 11236"', "property_type": "Non-Refrigerated Warehouse"},
    {"address": '"152 Ashland Place, Brooklyn, New York, 11201"', "property_type": "Parking"},
    {"address": '"435 E 55th St, New York, New York, 10022"', "property_type": "Parking"},
    {"address": '"163 East 84th Street, New York, New York, 10028"', "property_type": "Parking"},
    {"address": '"515 7th Avenue, New York, New York, 10018"', "property_type": "Parking"},
    {"address": '"201 WEST 75 STREET, New York, New York, 10023"', "property_type": "Parking"},
    {"address": '"5610 2nd Avenue, Brooklyn, New York, 11220"', "property_type": "Parking"},
    {"address": '"4162 Broadway, New York, New York, 10033"', "property_type": "Parking"},
    {"address": '"260 Myrtle Avenue, Brooklyn, New York, 11201"', "property_type": "Parking"},
    {"address": '"98-20 97 Avenue, Queens, New York, 11416"', "property_type": "Parking"},
    {"address": '"2400 Ryer Avenue, Bronx, New York, 10458"', "property_type": "Parking"},
    {"address": '"410 E 148 St, Bronx, New York, 10455"', "property_type": "Pre-school / Daycare"},
    {"address": '"2170 Mcdonald Ave, Brooklyn, New York, 11233"', "property_type": "Pre-school / Daycare"},
    {"address": '"170 LAWRENCE AVENUE, BROOKLYN, New York, 11230"', "property_type": "Pre-school / Daycare"},
    {"address": '"2863 Webster Avenue, Bronx, New York, 10458"', "property_type": "Pre-school / Daycare"},
    {"address": '"1841 Park Avenue, New York, New York, 10035"', "property_type": "Pre-school / Daycare"},
    {"address": '"460 Atlantic Ave, Brooklyn, New York, 11217"', "property_type": "Pre-school / Daycare"},
    {"address": '"58-71 56 DRIVE, QUEENS, New York, 11378"', "property_type": "Refrigerated Warehouse"},
    {"address": '"58-71 56 Drive, Maspeth, New York, 11378"', "property_type": "Refrigerated Warehouse"},
    {"address": '"340 Johnson Avenue, Brooklyn, New York, 11206"', "property_type": "Refrigerated Warehouse"},
    {"address": '"650 Fountain Ave, Brooklyn, New York, 11208"', "property_type": "Refrigerated Warehouse"},
    {"address": '"1376 Cromwell Avenue, Bronx, New York, 10452"', "property_type": "Self-Storage Facility"},
    {"address": '"47-36 VAN DAM STREET, Queens, New York, 11101"', "property_type": "Self-Storage Facility"},
    {"address": '"122-20 Merrick Boulevard, Queens, New York, 11434"', "property_type": "Self-Storage Facility"},
    {"address": '"1816 Boston Road, Bronx, New York, 10460"', "property_type": "Self-Storage Facility"},
    {"address": '"169-01 baisley blvd, queens, New York, 11434"', "property_type": "Self-Storage Facility"},
    {"address": '"5020 Broadway, New York, New York, 10034"', "property_type": "Self-Storage Facility"},
    {"address": '"2990 Cropsey Avenue, Brooklyn, New York, 11214"', "property_type": "Self-Storage Facility"},
    {"address": '"1151 East New York Avenue, Brooklyn, New York, 11212"', "property_type": "Self-Storage Facility"},
    {"address": '"301 West Fordham Road, Bronx, New York, 10468"', "property_type": "Self-Storage Facility"},
    {"address": '"252 Newport St, Brooklyn, New York, 11212"', "property_type": "Self-Storage Facility"},
    {"address": '"3511 Victory Blvd, Staten Island, New York, 10314"', "property_type": "Self-Storage Facility"},
    {"address": '"2558 e 18th st, Brooklyn, New York, 11235"', "property_type": "Supermarket / Grocery Store"},
    {"address": '"1507 Coney Island ave, Brooklyn, New York, 11230"', "property_type": "Supermarket / Grocery Store"},
    {"address": '"214 3rd St, Brooklyn, New York, 11215"', "property_type": "Supermarket / Grocery Store"},
    {"address": '"262 11 Avenue, New York, New York, 10001"', "property_type": "Vehicle Dealership"},
    {"address": '"48-40 34th St, Queens, New York, 11101"', "property_type": "Vocational School"},
    {"address": '"1215 E. GUN HILL RD, BRONX, New York, 10469"', "property_type": "Bowling Alley"},
    {"address": '"141 East Service Road, Staten Island, New York, 10314"', "property_type": "Bowling Alley"},
    {"address": '"30-05 Whitestone Expressway, Queens, New York, 11354"', "property_type": "Bowling Alley"},
    {"address": '"98-18 Rockaway Boulevard, Queens, New York, 11417"', "property_type": "Bowling Alley"}
]

# %%
addresses_short = [
    {"address": '"5020 Broadway, New York, New York, 10034"', "property_type": "Self-Storage Facility"},
    {"address": '"2990 Cropsey Avenue, Brooklyn, New York, 11214"', "property_type": "Self-Storage Facility"},
    {"address": '"1151 East New York Avenue, Brooklyn, New York, 11212"', "property_type": "Self-Storage Facility"},
    {"address": '"301 West Fordham Road, Bronx, New York, 10468"', "property_type": "Self-Storage Facility"},
    {"address": '"252 Newport St, Brooklyn, New York, 11212"', "property_type": "Self-Storage Facility"},
    {"address": '"3511 Victory Blvd, Staten Island, New York, 10314"', "property_type": "Self-Storage Facility"},
    {"address": '"2558 e 18th st, Brooklyn, New York, 11235"', "property_type": "Supermarket / Grocery Store"},
    {"address": '"1507 Coney Island ave, Brooklyn, New York, 11230"', "property_type": "Supermarket / Grocery Store"},
    {"address": '"214 3rd St, Brooklyn, New York, 11215"', "property_type": "Supermarket / Grocery Store"},
    {"address": '"262 11 Avenue, New York, New York, 10001"', "property_type": "Vehicle Dealership"},
    {"address": '"48-40 34th St, Queens, New York, 11101"', "property_type": "Vocational School"},
    {"address": '"1215 E. GUN HILL RD, BRONX, New York, 10469"', "property_type": "Bowling Alley"},
    {"address": '"141 East Service Road, Staten Island, New York, 10314"', "property_type": "Bowling Alley"},
    {"address": '"30-05 Whitestone Expressway, Queens, New York, 11354"', "property_type": "Bowling Alley"},
    {"address": '"98-18 Rockaway Boulevard, Queens, New York, 11417"', "property_type": "Bowling Alley"}
]

print(len(addresses_short))
# Out:
# 15

# %%
addresses_one = [
    {"address": '"5020 Broadway, New York, New York, 10034"', "property_type": "Self-Storage Facility"},
    {"address": '"2990 Cropsey Avenue, Brooklyn, New York, 11214"', "property_type": "Self-Storage Facility"},
    {"address": '"1151 East New York Avenue, Brooklyn, New York, 11212"', "property_type": "Self-Storage Facility"},
    {"address": '"1507 Coney Island ave, Brooklyn, New York, 11230"', "property_type": "Supermarket / Grocery Store"}
]

# %% [markdown]
# 1/12/26:
# - note where the follow up is necessary in adjusting the prompt to make it perform better
# - emphasize in the prompt that we NEED an email
# - add the property type for the GPT mini
#
# - they want to manually enrich it

# %% [markdown]
# #### GPT 4.1 (Web)

# %%
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

def get_address_info(address: str, property_type: str = None):

    response = client.responses.create(
        model="gpt-4.1-mini",
        tools=[{
            "type": "web_search",
            "search_context_size": "low"
        }],
        tool_choice="required",
        input=[
            {
                "role": "system",
                "content": ( f"""
                    You are an assistant that provides details about the owner and any businesses associated with a given address. Your primary objective is to identify and return information about the building owner (individual or company) at the address and include business information if present.
                    Context: For the provided address, here is additional context about a business that may operate there: {property_type}.
                    Instructions:
                        1. Return information for one building owner (individual or company) and, if available, one business operating at the address. If there are multiple possible results, return only the most prominent or relevant.
                        2. For each result, provide as much information as possible for the following fields, use additional searches to get more information about the building owner if need be, in order: ADDRESS (use the original input address, NOTHING ELSE) | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL | BUSINESS_NAME | BUSINESS_PHONE | BUSINESS_EMAIL.
                        3. If the building owner contact information comes back null, run another search, looking for the owner of the building owner with their phone number and relevant contact information. Do everything you can to get a building owner email, it is imperative to have it.
                        4. Use exactly this field order and separate all fields with a single pipe (|) character. Only return the fields provided, do not give any explanation of any kind in any field. 
                    ## Output Format
                    - Your output must be a single string, fields separated by a pipe (|), and in this order, with these EIGHT fields:
                    ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL | BUSINESS_NAME | BUSINESS_PHONE | BUSINESS_EMAIL
                    - All fields accept string values. For missing or unavailable information, use "Not Found."
                    Example:
                    123 Main St | John Doe | Acme Holdings LLC | 555-123-4567 | johndoe@email.com | Acme Supplies | 555-765-4321 | info@acmesupplies.com
                    If no relevant information is found, output:
                    Address | Not Found | Not Found | Not Found | Not Found | Not Found | Not Found | Not Found

                """
                )
            },
            {
                "role": "user",
                "content": f"""
                    Find the building owner and any business operating at:
                    Address to use in output: {address}
                    Property type context: {property_type or "Unknown"}

                    Return exactly:
                    ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL | BUSINESS_NAME | BUSINESS_PHONE | BUSINESS_EMAIL
                """
            }
        ],
        temperature=0.0,
        max_output_tokens=300
    )

    print(response.usage)

    parts = [p.strip() for p in response.output_text.split('|')]
    
    if len(parts) != 8:
        print(f"Warning: Expected 8 parts but got {len(parts)}. Response was: {response.output_text}")

    result = {
        "Address": address,
        "Owner Name": parts[1] if len(parts) > 1 else "Not Available",
        "Owner Company Name": parts[2] if len(parts) > 2 else "Not Available",
        "Owner Phone": parts[3] if len(parts) > 3 else "Not Available",
        "Owner email": parts[4] if len(parts) > 4 else "Not Available",
        "Business Name": parts[5] if len(parts) > 5 else "Not Available",
        "Business Phone": parts[6] if len(parts) > 6 else "Not Available",
        "Business Email": parts[7] if len(parts) > 7 else "Not Available"
    }
    
    return result
        

def process_addresses(address_data, output_file: str = "address_contacts.csv") -> pd.DataFrame:
    results = []
    
    for item in address_data:
        if isinstance(item, dict):
            address = item['address'].strip('"')
            prop_type = item.get('property_type')
        
        result = get_address_info(address, prop_type)
        results.append(result)

    df = pd.DataFrame(results)
    columns = ['Address', 'Owner Name', 'Owner Company Name', 'Owner Phone', 'Owner email', 'Business Name', 'Business Phone', 'Business Email']
    df = df[columns]
    df.to_csv(output_file, index=False, encoding='utf-8')
    return df

# %%
process_addresses(addresses_one)
# Out:
# ResponseUsage(input_tokens=9089, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=89, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9178)
# ResponseUsage(input_tokens=9091, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=89, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9180)
# ResponseUsage(input_tokens=9093, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=88, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9181)
# ResponseUsage(input_tokens=9096, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=90, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9186)
#                                              Address              Owner Name  \
# 0           5020 Broadway, New York, New York, 10034               Not Found
# ...

# %% [markdown]
# ### Just Building Owners

# %%
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

def get_address_info(address: str, property_type: str = None):

    response = client.responses.create(
        model="gpt-4.1-mini",
        tools=[{
            "type": "web_search",
            "search_context_size": "low"
        }],
        tool_choice="required",
        input=[
            {
                "role": "system",
                "content": ( f"""
                    You are an assistant that provides details about the owner and any businesses associated with a given address. Your primary objective is to identify and return information about the building owner (individual or company) at the address.
                    Context: For the provided address, here is additional context about a business that may operate there: {property_type}.
                    Instructions:
                        1. Return information for one building owner (individual or company) only. If there are multiple possible results, return only the most prominent or relevant.
                        2. For each result, provide as much information as possible for the following fields, in order: ADDRESS (use the original input address, NOTHING ELSE) | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL.
                        3. Use exactly this field order and separate all fields with a single pipe (|) character. Only return the fields provided, do not give any explanation of any kind in any field. 
                    ## Output Format
                    - Your output must be a single string, fields separated by a pipe (|), and in this order, with these EIGHT fields:
                    ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL
                    - All fields accept string values. For missing or unavailable information, use "Not Found."
                    Example:
                    123 Main St | John Doe | Acme Holdings LLC | 555-123-4567 | johndoe@email.com
                    If no relevant information is found, output:
                    Address | Not Found | Not Found | Not Found | Not Found

                """
                )
            },
            {
                "role": "user",
                "content": f"""
                    Find the building owner and any business operating at:
                    Address to use in output: {address}
                    Property type context: {property_type or "Unknown"}

                    Return exactly:
                    ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL
                """
            }
        ],
        temperature=0.0,
        max_output_tokens=300
    )

    print(response.usage)

    parts = [p.strip() for p in response.output_text.split('|')]
    
    if len(parts) != 5:
        print(f"Warning: Expected 8 parts but got {len(parts)}. Response was: {response.output_text}")

    result = {
        "Address": address,
        "Owner Name": parts[1] if len(parts) > 1 else "Not Available",
        "Owner Company Name": parts[2] if len(parts) > 2 else "Not Available",
        "Owner Phone": parts[3] if len(parts) > 3 else "Not Available",
        "Owner email": parts[4] if len(parts) > 4 else "Not Available",
    }
    
    return result
        

def process_buildings(address_data, output_file: str = "address_contacts.csv") -> pd.DataFrame:
    results = []
    
    for item in address_data:
        if isinstance(item, dict):
            address = item['address'].strip('"')
            prop_type = item.get('property_type')
        
        result = get_address_info(address, prop_type)
        results.append(result)

    df = pd.DataFrame(results)
    columns = ['Address', 'Owner Name', 'Owner Company Name', 'Owner Phone', 'Owner email']
    df = df[columns]
    df.to_csv(output_file, index=False, encoding='utf-8')
    return df

# %%
process_buildings(addresses_one)
# Out:
# ResponseUsage(input_tokens=8940, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=73, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9013)
# ResponseUsage(input_tokens=8942, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=72, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9014)
# ResponseUsage(input_tokens=8944, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=81, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9025)
# ResponseUsage(input_tokens=8947, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=91, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9038)
#                                              Address  \
# 0           5020 Broadway, New York, New York, 10034
# 1     2990 Cropsey Avenue, Brooklyn, New York, 11214
# 2  1151 East New York Avenue, Brooklyn, New York,...
# ...

# %% [markdown]
# ## Legacy Below

# %% [markdown]
# ### GPT 4.1 Normal

# %%
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

def get_address_info(address: str, property_type: str = None) -> Dict[str, str]:
    response = client.chat.completions.create(
        model="gpt-4.1",
        tools = [{"type": "web_search"}],
        messages=[
            {
                "role": "system", 
                "content": f"""
                    You are an assistant that provides details about the owner and any businesses associated with a given address. Your primary objective is to identify and return information about the building owner (individual or company) at the address and include business information if present.
                    Context: For the provided address, here is additional context about a business that may operate there: {property_type}.
                    Instructions:
                        1. Search for and return information for one building owner (individual or company) and, if available, one business operating at the address. If there are multiple possible results, return only the most prominent or relevant.
                        2. For each result, provide as much information as possible for the following fields, in order: ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL | BUSINESS_NAME | BUSINESS_PHONE | BUSINESS_EMAIL.
                        3. If any field is unknown or cannot be found, use "Not Found" as the value. Do not leave any fields blank.
                        4. Use exactly this field order and separate all fields with a single pipe (|) character.
                        5. When faced with ambiguous or conflicting information, select the most reliable result based on the sources available.
                        6. After compiling the information, briefly validate completeness by confirming that all eight fields are present and none are blank; self-correct if any issues are found.
                        7. Only return the fields provided, do not include any either thought process and do not hallucinate or make up any answers.
                    ## Output Format
                    - Your output must be a single string, fields separated by a pipe (|), and in this order, with these EIGHT fields:
                    ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL | BUSINESS_NAME | BUSINESS_PHONE | BUSINESS_EMAIL
                    - All fields accept string values. For missing or unavailable information, use "Not Found."
                    Example:
                    123 Main St | John Doe | Acme Holdings LLC | 555-123-4567 | johndoe@email.com | Acme Supplies | 555-765-4321 | info@acmesupplies.com
                    If no relevant information is found, output:
                    Address | Not Found | Not Found | Not Found | Not Found | Not Found | Not Found | Not Found
                """
            },
            {
                "role": "user", 
                "content": f"Please provide information for this address: {address}"
            }
        ],
        temperature=0.1,
        max_completion_tokens=100
    )
    
    parts = [p.strip() for p in response.choices[0].message.content.split('|')]
    
    if len(parts) != 8:
        print(f"Warning: Expected 8 parts but got {len(parts)}. Response was: {response.choices[0].message.content}")

    result = {
        "Address": parts[0] if len(parts) > 0 else address,
        "Owner Name": parts[1] if len(parts) > 1 else "Not Available",
        "Owner Company Name": parts[2] if len(parts) > 2 else "Not Available",
        "Owner Phone": parts[3] if len(parts) > 3 else "Not Available",
        "Owner email": parts[4] if len(parts) > 4 else "Not Available",
        "Business Name": parts[5] if len(parts) > 5 else "Not Available",
        "Business Phone": parts[6] if len(parts) > 6 else "Not Available",
        "Business Email": parts[7] if len(parts) > 7 else "Not Available"
    }
    
    return result
        

def process_addresses(address_data, output_file: str = "address_contacts.csv") -> pd.DataFrame:
    results = []
    
    for item in address_data:
        if isinstance(item, dict):
            address = item['address'].strip('"')
            prop_type = item.get('property_type')
        
        # print(f"Processing: {address}" + (f" (Type: {prop_type})" if prop_type else ""))
        # print(f"Processing: {address}")
        result = get_address_info(address, prop_type)
        results.append(result)
        # print(f"  - Status: {result['Status']}")
    
    df = pd.DataFrame(results)
    columns = ['Address', 'Owner Name', 'Owner Company Name', 'Owner Phone', 'Owner email', 'Business Name', 'Business Phone', 'Business Email']
    df = df[columns]
    df.to_csv(output_file, index=False, encoding='utf-8')
    return df

# %%
# single test

response = client.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {
            "role": "system", 
            "content": f"""
                You are an assistant that provides details"""
        },
        {
            "role": "user", 
            "content": f"Can you tell me the building owner at this address, 5020 Broadway, New York, NY 10034, or a business that may be there and its contact information? Tell me if you do not know"
        }
    ],
    temperature=0.1,
    max_completion_tokens=300
)

print(response.choices[0].message.content)

# %% [markdown]
# ### GPT 5.2

# %%
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

def get_address_info(address: str, property_type: str = None) -> Dict[str, str]:
    response = client.responses.create(
        model="gpt-5",
        reasoning={"effort": "low"},
        tools = [{"type": "web_search"}],
        input=[
            {
                "role": "system",
                "content": f"""
                    You are an assistant that provides details about the owner and any businesses associated with a given address. Your primary objective is to identify and return information about the building owner (individual or company) at the address and include business information if present.
                    Context: For the provided address, here is additional context about a business that may operate there: {property_type}.
                    Instructions:
                        1. Search for and return information for one building owner (individual or company) and, if available, one business operating at the address. If there are multiple possible results, return only the most prominent or relevant.
                        2. For each result, provide as much information as possible for the following fields, in order: ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL | BUSINESS_NAME | BUSINESS_PHONE | BUSINESS_EMAIL.
                        3. If any field is unknown or cannot be found, use "Not Found" as the value. Do not leave any fields blank.
                        4. Use exactly this field order and separate all fields with a single pipe (|) character.
                        5. When faced with ambiguous or conflicting information, select the most reliable result based on the sources available.
                        6. After compiling the information, briefly validate completeness by confirming that all eight fields are present and none are blank; self-correct if any issues are found.
                        7. Only return the fields provided. You may make reasonable inferences based on common patterns.
                    ## Output Format
                    - Your output must be a single string, fields separated by a pipe (|), and in this order, with these EIGHT fields:
                    ADDRESS | OWNER_NAME | OWNER_COMPANY_NAME | OWNER_PHONE | OWNER_EMAIL | BUSINESS_NAME | BUSINESS_PHONE | BUSINESS_EMAIL
                    - All fields accept string values. For missing or unavailable information, use "Not Found."
                    Example:
                    123 Main St | John Doe | Acme Holdings LLC | 555-123-4567 | johndoe@email.com | Acme Supplies | 555-765-4321 | info@acmesupplies.com
                    If no relevant information is found, output:
                    Address | Not Found | Not Found | Not Found | Not Found | Not Found | Not Found | Not Found
                """
            },
            {
                "role": "user",
                "content": f"Please provide information for this address: {address}"
            }
        ],
        max_output_tokens=100
    )

    result = response.output_text

    parts = [p.strip() for p in result.split('|')]
    
    if len(parts) != 8:
        print(f"Warning: Expected 8 parts but got {len(parts)}. Response was: {result}")

    result = {
        "Address": parts[0] if len(parts) > 0 else address,
        "Owner Name": parts[1] if len(parts) > 1 else "Not Available",
        "Owner Company Name": parts[2] if len(parts) > 2 else "Not Available",
        "Owner Phone": parts[3] if len(parts) > 3 else "Not Available",
        "Owner email": parts[4] if len(parts) > 4 else "Not Available",
        "Business Name": parts[5] if len(parts) > 5 else "Not Available",
        "Business Phone": parts[6] if len(parts) > 6 else "Not Available",
        "Business Email": parts[7] if len(parts) > 7 else "Not Available"
    }
    
    return result
        

def process_addresses(address_data, output_file: str = "address_contacts.csv") -> pd.DataFrame:
    results = []
    
    for item in address_data:
        if isinstance(item, dict):
            address = item['address'].strip('"')
            prop_type = item.get('property_type')
        
        # print(f"Processing: {address}" + (f" (Type: {prop_type})" if prop_type else ""))
        print(f"Processing: {address}")
        result = get_address_info(address, prop_type)
        results.append(result)
        # print(f"  - Status: {result['Status']}")
    
    df = pd.DataFrame(results)
    columns = ['Address', 'Owner Name', 'Owner Company Name', 'Owner Phone', 'Owner email', 'Business Name', 'Business Phone', 'Business Email']
    df = df[columns]
    df.to_csv(output_file, index=False, encoding='utf-8')
    return df

# %%
process_addresses(addresses_one)
# Out:
# Processing: 5020 Broadway, New York, New York, 10034
# ...
#   Address     Owner Name Owner Company Name    Owner Phone    Owner email  \
# 0          Not Available      Not Available  Not Available  Not Available
#
#    Business Name Business Phone Business Email
# 0  Not Available  Not Available  Not Available

# %%
# single test

response = client.responses.create(
        model="gpt-5.2",
        reasoning={"effort": "none"},  # IMPORTANT for deterministic behavior
        input=[
            {
                "role": "system",
                "content": f"""
                    You are an assistant that provides details
                """
            },
            {
                "role": "user",
                "content": f"Can you tell me the building owner at this address, 5020 Broadway, New York, NY 10034, or a business that may be there and its contact information? Tell me if you do not know"
            }
        ],
        max_output_tokens=100
    )

result = response.output_text
print(result)
# Out:
# I don’t know the current building owner or the current business/contact information for **5020 Broadway, New York, NY 10034** from my internal knowledge alone, and I don’t have live access to pull it up directly.
#
# Here are reliable ways to find it quickly:
#
# ## 1) Find the building owner (NYC official sources)
# **NYC Department of Finance – ACRIS (property records)**
# - https://a836-acris.nyc.gov/
